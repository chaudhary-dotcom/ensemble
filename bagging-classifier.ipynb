# %%
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
X,y = make_classification(n_samples=10000, n_features=10, n_informative=2)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %%
dt = DecisionTreeClassifier(random_state=2)
dt.fit(X_train,y_train)
y_pred = dt.predict(X_test)
print('Accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy score:  0.8555

# %% [markdown]
# ## 1. Bagging

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.5,
    bootstrap=True,
    random_state=42
    
)

bag.fit(X_train,y_train)
y_pred = bag.predict(X_test)
print('Bagging score: ', accuracy_score(y_test, y_pred))
# Out:
# Bagging score:  0.906

# %% [markdown]
# ## 2. Bagging Using SVM

# %%
bag = BaggingClassifier(
    estimator=SVC(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=2
)
bag.fit(X_train,y_train)
y_pred = bag.predict(X_test)
print('Accuracy of SVM: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy of SVM:  0.9145

# %% [markdown]
# ## 3. Pasting

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25, 
    bootstrap=False,
    random_state=2,
    verbose=1,
    n_jobs=-1
)

bag.fit(X_train, y_train)
y_pred = bag.predict(X_test)
print('Accuracy of Pasting: ', accuracy_score(y_test, y_pred))
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    6.0s remaining:   18.3s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    6.2s finished
# Accuracy of Pasting:  0.9095
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.1s finished

# %% [markdown]
# ## 4. Random Subspaces

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=1.0,
    bootstrap=False,
    bootstrap_features=True,
    max_features = 0.5,
    random_state=2
    
)

bag.fit(X_train, y_train)
y_pred = bag.predict(X_test)
print('Accuracy of Random subspaces: ', accuracy_score(y_test, y_pred))
# Out:
# Accuracy of Random subspaces:  0.911

# %%
bag.estimators_samples_[0].shape
# Out:
# (8000,)

# %%
bag.estimators_features_[5].shape
# Out:
# (5,)

# %% [markdown]
# ## 4. Random Patches

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    max_features=0.5,
    bootstrap_features=True,
    random_state=2,
    verbose=1,
    n_jobs=-1
)

bag.fit(X_train, y_train)
y_pred = bag.predict(X_test)
print('Accuracy score of random patches: ', accuracy_score(y_test, y_pred))
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    5.1s remaining:   15.4s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    5.3s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# Accuracy score of random patches:  0.9125
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.0s remaining:    0.3s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.2s finished

# %%
bag.estimators_samples_
# Out:
# [array([3314, 3532, 5663, ..., 3523, 7892, 7609], dtype=int32),
#  array([5951, 6631, 3196, ..., 3369, 3939,  578], dtype=int32),
#  array([   0, 7708,  385, ..., 6809, 7035, 7969], dtype=int32),
#  array([1180, 6722, 3129, ..., 4072, 5397, 1001], dtype=int32),
#  array([6192, 4869, 1168, ..., 6095, 6713,  643], dtype=int32),
#  array([3316, 3831,  147, ..., 4205, 4272, 6892], dtype=int32),
#  array([6489, 5699, 5765, ..., 4018,  968, 3880], dtype=int32),
#  array([2855, 2831, 7260, ..., 6645, 7951, 1700], dtype=int32),
#  array([ 537, 1627,  517, ..., 4411,  675, 6290], dtype=int32),
#  array([6807, 7373, 1063, ..., 5889, 4072, 7289], dtype=int32),
#  array([6078, 7870, 5240, ..., 3635,  132, 5776], dtype=int32),
#  array([4194, 1988, 5419, ...,  734, 5872,  789], dtype=int32),
#  array([4182, 6580, 4523, ..., 5571, 6127, 4325], dtype=int32),
#  array([4733, 6916,  852, ..., 3063, 6483, 5084], dtype=int32),
#  array([2451, 7653, 3563, ..., 3282,  914, 6249], dtype=int32),
#  array([ 239, 3864, 5428, ..., 1291, 4887, 5108], dtype=int32),
#  array([6418, 6435, 6626, ..., 5225, 6998, 7751], dtype=int32),
#  array([4484, 6718, 7823, ..., 7004, 4433, 1949], dtype=int32),
#  array([1904,  873, 4213, ..., 2119, 4344, 4892], dtype=int32),
#  array([1633, 3094, 4119, ..., 3288, 6361, 5260], dtype=int32),
#  array([3359, 4736, 7313, ..., 5167, 2727, 6800], dtype=int32),
#  array([6804, 4983, 2904, ..., 6594, 1889, 7773], dtype=int32),
#  array([ 851, 2326, 5497, ..., 3636, 1900, 6550], dtype=int32),
#  array([1069, 2825, 4004, ..., 4958,  400, 3435], dtype=int32),
#  array([1838, 3084, 3489, ..., 6619, 1032, 7834], dtype=int32),
#  array([5625, 2898,  772, ...,  288, 6046, 2067], dtype=int32),
#  array([2143, 2671, 7791, ..., 2295, 7290, 1787], dtype=int32),
#  array([7425,  284, 3505, ...,  488, 6734, 2191], dtype=int32),
#  array([5532, 5597, 4916, ..., 1234, 3230, 1337], dtype=int32),
#  array([2972,  922, 2321, ..., 1546,    9, 6936], dtype=int32),
#  array([5319, 6971, 2967, ..., 1679, 1233, 4561], dtype=int32),
#  array([3721, 6672, 2982, ..., 4577, 4297, 5919], dtype=int32),
#  array([3658, 6252, 6415, ...,  173, 5236, 3947], dtype=int32),
#  array([3766, 6801,  937, ..., 7428, 4922,  135], dtype=int32),
#  array([4166, 1572, 6499, ...,  953, 4267, 7132], dtype=int32),
#  array([5403, 1324, 7734, ..., 3091, 7525, 2118], dtype=int32),
#  array([2564, 5711, 6129, ..., 4275, 3833, 5598], dtype=int32),
#  array([1362, 3994, 3577, ..., 5668, 4895, 3435], dtype=int32),
#  array([2043, 2720, 4546, ..., 6260,  118,  124], dtype=int32),
#  array([7654, 7501,   13, ..., 5756, 4167,  945], dtype=int32),
#  array([6421, 3177, 2579, ..., 1187, 7164, 5111], dtype=int32),
#  array([2689, 7728, 3874, ..., 3280, 2875, 2115], dtype=int32),
#  array([6924, 3361,  639, ..., 7716, 2140, 7969], dtype=int32),
#  array([6953, 2491, 7997, ..., 1178, 6662, 7767], dtype=int32),
#  array([5348, 6951, 2599, ..., 5753,  849, 1696], dtype=int32),
#  array([ 641, 1234, 6426, ..., 2466,  829, 7605], dtype=int32),
#  array([7276, 2693, 4671, ..., 2746, 7209, 5708], dtype=int32),
#  array([4711,  863, 3280, ..., 3954, 3396, 6977], dtype=int32),
#  array([4649, 4259, 2835, ..., 4948, 5197, 5974], dtype=int32),
#  array([5065, 6929, 7904, ..., 6344, 3194, 1719], dtype=int32),
#  array([7098, 6799, 3692, ..., 2322, 5833, 3903], dtype=int32),
#  array([6319,  148, 1587, ..., 4585, 7426, 4730], dtype=int32),
#  array([ 307, 4033, 2974, ..., 6241, 4946, 1772], dtype=int32),
#  array([4350,  883, 1870, ..., 7143,  635, 6899], dtype=int32),
#  array([ 243, 4801,  323, ..., 2974, 6296, 7188], dtype=int32),
#  array([2986, 7132, 3344, ..., 4445, 1148, 5004], dtype=int32),
#  array([6149, 5128, 3033, ..., 2594,  985, 1727], dtype=int32),
#  array([3214, 1240, 5613, ..., 4504, 1558, 3502], dtype=int32),
#  array([2786, 4870, 3253, ..., 6817, 6644, 4360], dtype=int32),
#  array([3208, 5837, 2409, ..., 4588, 5320, 5235], dtype=int32),
#  array([6562, 4965, 4130, ..., 2497, 4328, 4907], dtype=int32),
#  array([2091, 1838, 3929, ...,  173, 6764, 4626], dtype=int32),
#  array([ 965, 1775, 4086, ..., 3762, 7568, 1532], dtype=int32),
#  array([7676, 4485, 7756, ..., 6717, 6958, 7586], dtype=int32),
#  array([5682, 1401, 3175, ...,  439, 6304, 2110], dtype=int32),
#  array([7405,  295, 2546, ..., 5024, 2924, 2174], dtype=int32),
#  array([2695, 4085,  622, ..., 5028, 6691, 2500], dtype=int32),
#  array([6234, 1287, 5963, ...,  352, 7165, 5177], dtype=int32),
#  array([6233, 4300, 3297, ..., 4132, 2281, 2832], dtype=int32),
#  array([1009, 4293, 1245, ..., 4826, 4175, 5592], dtype=int32),
#  array([ 353, 3347, 6305, ..., 3024, 6995,  947], dtype=int32),
#  array([6497, 5000, 5971, ..., 4242, 5429, 4534], dtype=int32),
#  array([ 608, 7322, 7881, ..., 1175, 4307, 4684], dtype=int32),
#  array([3030, 1852, 6823, ..., 1401, 3365, 6515], dtype=int32),
#  array([6518, 5643, 1594, ..., 5763, 3003, 5514], dtype=int32),
#  array([6823, 1271, 3169, ..., 7236, 2452, 6549], dtype=int32),
#  array([1418, 1105, 4016, ..., 1796, 4337, 2314], dtype=int32),
#  array([2718, 7885, 3892, ..., 7978, 3269,  271], dtype=int32),
#  array([1763, 1988, 4725, ..., 3989, 3429, 7517], dtype=int32),
#  array([3858, 4078,  654, ..., 7160, 2824, 5815], dtype=int32),
#  array([3819, 1740, 1358, ..., 2845, 3022, 4140], dtype=int32),
#  array([6015, 6450, 4721, ..., 2361, 6313, 1816], dtype=int32),
#  array([3231, 2818, 4337, ..., 2542, 4580, 5501], dtype=int32),
#  array([2909, 6141, 6176, ...,  273, 6724, 4372], dtype=int32),
#  array([  79, 2250, 1361, ..., 5896, 2590, 5615], dtype=int32),
#  array([7088, 7604, 4702, ..., 6476, 6264, 4283], dtype=int32),
#  array([1355, 5299, 2052, ..., 7787,  475, 3627], dtype=int32),
#  array([4737, 2825,   74, ...,   10, 6624, 2407], dtype=int32),
#  array([5998, 3680, 7082, ...,  869, 3313, 4976], dtype=int32),
#  array([4229, 4125, 7283, ..., 6800, 1118, 4836], dtype=int32),
#  array([6949, 5780, 2727, ..., 4598, 7164, 5254], dtype=int32),
#  array([ 451, 3954, 4352, ..., 3604, 3989,  890], dtype=int32),
#  array([3567, 7475,  705, ..., 2977, 6466, 7782], dtype=int32),
#  array([7274, 2088,  728, ..., 6931, 1668,  962], dtype=int32),
#  array([2660, 5330, 5412, ..., 1455, 5383, 5200], dtype=int32),
#  array([3489, 4493, 7373, ..., 4134,   72, 4038], dtype=int32),
#  array([1838, 2281, 2743, ..., 1857, 7585, 2354], dtype=int32),
#  array([7880, 1846, 7480, ..., 5805, 4487, 6895], dtype=int32),
#  array([5722, 2543,  102, ..., 7562, 1000, 3249], dtype=int32),
#  array([ 294, 6610, 2346, ..., 5429, 6099, 5440], dtype=int32),
#  array([ 525, 7349, 4449, ..., 4515, 4641, 2980], dtype=int32),
#  array([3478, 7794, 5492, ..., 5841, 3940, 2417], dtype=int32),
#  array([1761, 7682, 4089, ..., 6556, 6743, 2453], dtype=int32),
#  array([2298, 2776, 4956, ..., 1237, 7316, 5101], dtype=int32),
#  array([5655, 6755, 4436, ...,  323, 2567,  997], dtype=int32),
#  array([7805, 2593, 2681, ..., 1597, 2888, 5066], dtype=int32),
#  array([ 694, 1454,  403, ..., 3890, 5420, 1635], dtype=int32),
#  array([3830, 2479, 7817, ..., 3564, 5963, 4282], dtype=int32),
#  array([1948, 1654, 3545, ..., 2909, 2991,   20], dtype=int32),
#  array([3638, 5312, 2834, ..., 2380, 1926, 7041], dtype=int32),
#  array([4878, 1904, 7516, ..., 7000, 4804, 1459], dtype=int32),
#  array([1695,  316, 4090, ..., 5336, 7537, 1122], dtype=int32),
#  array([1884, 2661, 2627, ..., 2537, 5190, 5932], dtype=int32),
#  array([7502, 5693, 4245, ..., 1745,  746, 5718], dtype=int32),
#  array([2222, 1564, 6568, ..., 3335, 7349, 5380], dtype=int32),
#  array([ 103, 1343, 5000, ..., 3100, 1800, 3362], dtype=int32),
#  array([4527, 2171, 6433, ..., 5689, 6817, 5325], dtype=int32),
#  array([ 434, 7208, 5748, ..., 1628, 4495, 7707], dtype=int32),
#  array([1932, 4185, 1967, ..., 6627, 7347, 3260], dtype=int32),
#  array([7958,  705, 6804, ..., 2194, 4742, 7491], dtype=int32),
#  array([6066, 7369, 3094, ..., 2130, 2685, 2681], dtype=int32),
#  array([5520, 7893, 5347, ..., 3600, 6729, 6808], dtype=int32),
#  array([3718, 5590, 1006, ..., 4641, 3405, 4669], dtype=int32),
#  array([6354, 1124, 4281, ...,  295, 2204, 1021], dtype=int32),
#  array([7463, 2556, 3111, ..., 7765, 4354, 2853], dtype=int32),
#  array([7627,  728,  686, ..., 2845, 6668, 2692], dtype=int32),
#  array([2313, 6427, 1683, ..., 2551, 3152, 2881], dtype=int32),
#  array([ 996, 2652, 1160, ..., 6659, 7038, 6580], dtype=int32),
#  array([3609, 6350, 6047, ..., 3782, 4601, 5558], dtype=int32),
#  array([1726, 5530, 2484, ..., 4001, 1615,  887], dtype=int32),
#  array([1208, 1590, 3565, ..., 1162,  364, 2146], dtype=int32),
#  array([5673, 1830, 1863, ..., 6657, 3366, 7376], dtype=int32),
#  array([7133, 1788, 3256, ..., 2747, 5664, 4042], dtype=int32),
#  array([5949, 7499, 7688, ..., 4042, 2428, 5475], dtype=int32),
#  array([5310, 3264, 4630, ...,  612, 2850, 1466], dtype=int32),
#  array([1879,  544, 4984, ...,  521, 7615, 7946], dtype=int32),
#  array([2198, 5579, 5001, ..., 3724, 4651, 6723], dtype=int32),
#  array([5475,  368, 2874, ..., 6346, 3165, 7524], dtype=int32),
#  array([3453, 4471, 4007, ..., 4633, 2770,  310], dtype=int32),
#  array([1490,  109, 6440, ..., 1112, 7421, 5822], dtype=int32),
#  array([3481,  608, 1183, ..., 1208, 7252,  136], dtype=int32),
#  array([7824, 2121, 1423, ..., 7566, 7126, 7055], dtype=int32),
#  array([2789, 4336, 4233, ..., 2150, 1526, 1229], dtype=int32),
#  array([3822,  666, 2340, ..., 5425, 2300,  641], dtype=int32),
#  array([5818, 7548, 4995, ..., 7447,   61,  152], dtype=int32),
#  array([ 431, 2426, 4193, ..., 7945, 1261, 6927], dtype=int32),
#  array([6020,  132,  145, ..., 2243, 2595, 5703], dtype=int32),
#  array([6313, 7703, 6682, ..., 1089, 5774, 3531], dtype=int32),
#  array([4491, 1204, 3040, ..., 6462, 6254, 4004], dtype=int32),
#  array([6282, 1193, 1145, ..., 7175, 6833, 5786], dtype=int32),
#  array([ 631, 2893, 6677, ...,  604, 5641, 1991], dtype=int32),
#  array([7820, 6570, 5851, ..., 7666, 1782, 5446], dtype=int32),
#  array([2922, 5967, 1707, ..., 3004, 4715,  931], dtype=int32),
#  array([6813,  652, 2578, ...,  276, 1895, 2327], dtype=int32),
#  array([7726,  742, 4911, ..., 2408, 2734,  555], dtype=int32),
#  array([3526, 1942, 6432, ..., 1618, 5352, 3520], dtype=int32),
#  array([1483, 7186, 7022, ..., 4776, 4954, 2810], dtype=int32),
#  array([5209, 6368,  467, ..., 4694,  647, 2322], dtype=int32),
#  array([3681, 6805, 1985, ...,    5, 2154, 1627], dtype=int32),
#  array([6632, 1770, 6770, ..., 4602,  237, 7296], dtype=int32),
#  array([6578, 5061, 4088, ..., 4026, 7300, 1768], dtype=int32),
#  array([  76, 3617, 1923, ..., 6573, 2114, 5178], dtype=int32),
#  array([3092, 3363, 6207, ..., 6298, 5344, 3385], dtype=int32),
#  array([7363, 2312, 4815, ..., 3395, 4193, 7925], dtype=int32),
#  array([ 855, 4076, 7524, ..., 3985,  274, 2043], dtype=int32),
#  array([3801, 4459, 6665, ..., 6516, 3161,  818], dtype=int32),
#  array([1185, 3455, 5299, ..., 1640,   84, 2999], dtype=int32),
#  array([ 422, 3517, 1292, ..., 2071, 7870, 4419], dtype=int32),
#  array([4493, 5986,  188, ..., 1207, 7804, 7918], dtype=int32),
#  array([5911, 1701, 2174, ..., 3931, 7035, 6680], dtype=int32),
#  array([3511, 6593,   18, ..., 2404, 2709, 7880], dtype=int32),
#  array([1406, 7571, 4028, ..., 6571, 4718, 1528], dtype=int32),
#  array([5924, 2765, 1943, ..., 7737, 1376, 7034], dtype=int32),
#  array([6347, 5338, 6381, ..., 3539,  912, 1260], dtype=int32),
#  array([6883,  245, 1279, ..., 7321, 2713, 7274], dtype=int32),
#  array([ 533, 5665, 4129, ..., 1192,  111, 3041], dtype=int32),
#  array([2774, 3349, 7109, ...,  943, 5373, 6908], dtype=int32),
#  array([2561, 4506, 6838, ..., 2842, 4335,  501], dtype=int32),
#  array([2041, 2038,  868, ..., 4186, 5947,  976], dtype=int32),
#  array([5950, 2127, 2375, ..., 4078, 1565, 6728], dtype=int32),
#  array([4516, 3485,  621, ..., 2783, 1833, 2894], dtype=int32),
#  array([5140, 2898, 1882, ..., 4028, 6672,  657], dtype=int32),
#  array([5524, 4587, 1682, ..., 4518, 2158, 5806], dtype=int32),
#  array([ 280, 4042, 4713, ..., 7204, 7989,  113], dtype=int32),
#  array([4414, 7107, 5559, ..., 2270, 2249, 4603], dtype=int32),
#  array([4426, 3266, 6580, ..., 1845, 4757, 2894], dtype=int32),
#  array([6030, 7680,  631, ...,  174,  221, 3369], dtype=int32),
#  array([6451, 6167, 1434, ..., 4703, 3167, 1164], dtype=int32),
#  array([1943, 1226,  422, ..., 5690,  111, 3166], dtype=int32),
#  array([6070, 1671, 6187, ..., 5480, 6260, 7302], dtype=int32),
#  array([5895,   85, 2432, ..., 6777, 1847, 2001], dtype=int32),
#  array([7684, 5356, 2582, ..., 6154,  582, 3491], dtype=int32),
#  array([7885,  107, 1035, ..., 5882,  854, 5304], dtype=int32),
#  array([6144, 7176, 3428, ..., 7919, 4467,  692], dtype=int32),
#  array([ 706, 5027, 4205, ..., 3750, 4079, 5853], dtype=int32),
#  array([1990, 2765, 1067, ..., 4777,  172, 2993], dtype=int32),
#  array([4846,  199, 5332, ..., 4967, 2784, 4075], dtype=int32),
#  array([5099, 7024,   14, ..., 5056, 4107, 7742], dtype=int32),
#  array([6505, 4391, 1071, ..., 2280, 3142, 6371], dtype=int32),
#  array([   6, 4395, 4396, ..., 2929,  117,  831], dtype=int32),
#  array([6856, 4025, 3215, ..., 2093, 7230, 7606], dtype=int32),
#  array([6770, 1213, 7346, ..., 5044, 6297, 4683], dtype=int32),
#  array([6138, 7983, 3187, ..., 5768, 5950, 2984], dtype=int32),
#  array([7495, 6576, 2384, ..., 6581, 2837, 7346], dtype=int32),
#  array([2398, 5966, 2018, ...,  263, 4290, 1768], dtype=int32),
#  array([5182, 7325, 2265, ..., 4538,  687, 2621], dtype=int32),
#  array([5222, 4596,  812, ..., 5210, 4139, 7825], dtype=int32),
#  array([3416, 2493, 4619, ..., 1932,  172, 3792], dtype=int32),
#  array([6045, 1951, 3788, ..., 4449, 1390, 4503], dtype=int32),
#  array([3447, 3955, 1821, ..., 6388,  297, 3384], dtype=int32),
#  array([4409,   72, 3888, ..., 4159,  761, 3981], dtype=int32),
#  array([ 483, 4516, 3355, ..., 3978,   96, 2745], dtype=int32),
#  array([4090, 7529, 5366, ..., 7535, 2575, 3935], dtype=int32),
#  array([1209, 6404, 4964, ..., 2903, 1765, 7812], dtype=int32),
#  array([3463, 3393, 1803, ...,  877, 2505, 1022], dtype=int32),
#  array([4061, 3910, 7787, ..., 2930, 4973, 7657], dtype=int32),
#  array([2914,  457, 5949, ..., 7434, 1436, 1383], dtype=int32),
#  array([ 654, 7624,  272, ..., 3181, 2605, 7854], dtype=int32),
#  array([1967, 2314,  222, ..., 6544, 4907, 6306], dtype=int32),
#  array([7769, 7003, 4756, ..., 3078, 7197,  537], dtype=int32),
#  array([5388, 2685, 3052, ..., 4604, 7838, 2770], dtype=int32),
#  array([3277, 4226, 4444, ...,    0, 5746,    3], dtype=int32),
#  array([6762, 2012, 1348, ..., 4513, 1962, 2398], dtype=int32),
#  array([ 548, 2382, 6344, ..., 3599, 2147, 6866], dtype=int32),
#  array([6582, 1735, 6088, ..., 7253,  974, 3660], dtype=int32),
#  array([3954, 5549, 6201, ...,  284, 6663, 2050], dtype=int32),
#  array([1264, 5437, 1065, ..., 4147, 7075, 4431], dtype=int32),
#  array([ 299, 1733, 3963, ..., 6188, 7296, 4994], dtype=int32),
#  array([5986, 7672, 2263, ..., 5086, 6172, 1874], dtype=int32),
#  array([7863, 5515, 6666, ..., 1892, 6644, 2976], dtype=int32),
#  array([6682,  276,  239, ..., 3012, 7718, 5035], dtype=int32),
#  array([ 218, 4719, 1591, ..., 5136, 1562, 7938], dtype=int32),
#  array([ 517, 2144, 6251, ..., 2833, 4434, 3814], dtype=int32),
#  array([7608, 3954, 6493, ..., 7263, 7178, 6627], dtype=int32),
#  array([3015,  989,  830, ..., 1156, 6598, 4704], dtype=int32),
#  array([5020, 4937, 5054, ..., 6449, 4026, 4673], dtype=int32),
#  array([3883,  281, 4573, ..., 6955, 5088, 1878], dtype=int32),
#  array([4732, 4583, 1687, ..., 4405,  583, 3181], dtype=int32),
#  array([ 363, 5638, 3191, ...,  840, 5125, 5399], dtype=int32),
#  array([1815, 2656, 1426, ..., 4388,  716, 6786], dtype=int32),
#  array([ 305, 2586, 5379, ..., 1270, 2919, 3823], dtype=int32),
#  array([5707,   91, 1687, ..., 3230, 2531, 1187], dtype=int32),
#  array([2433, 7629, 4848, ..., 1337, 3677, 5422], dtype=int32),
#  array([3339,  918,  847, ..., 7245, 6178, 3773], dtype=int32),
#  array([6336, 5746, 5891, ..., 6783, 3444, 4530], dtype=int32),
#  array([2808, 2872, 2177, ..., 5662, 5308,  667], dtype=int32),
#  array([2360,  396, 2817, ..., 3239, 4320, 5290], dtype=int32),
#  array([6159,  926, 1725, ..., 1760, 6086, 4093], dtype=int32),
#  array([6400, 5399, 5269, ..., 1255, 1216,  600], dtype=int32),
#  array([6890, 2547, 1363, ..., 4749, 7367, 7266], dtype=int32),
#  array([3364, 5048, 6768, ..., 5513, 1399, 6676], dtype=int32),
#  array([7336, 1374, 5742, ..., 2566, 1609, 6421], dtype=int32),
#  array([6011, 5943,  598, ..., 2986, 6478, 1034], dtype=int32),
#  array([4622, 6039, 3608, ..., 5585, 4169,  690], dtype=int32),
#  array([6259, 7802,  130, ..., 4191,  529, 6873], dtype=int32),
#  array([7607, 4966, 1553, ..., 6854, 3367, 7847], dtype=int32),
#  array([4759, 1709, 6367, ..., 5547, 3247, 2066], dtype=int32),
#  array([ 724, 6964, 5941, ..., 3554, 3383,  968], dtype=int32),
#  array([1405, 6082, 1596, ..., 7414, 4867, 1889], dtype=int32),
#  array([7287, 4736,  562, ..., 3854,  483, 3947], dtype=int32),
#  array([2800,  430,  335, ...,  248, 3046, 4296], dtype=int32),
#  array([6601, 3120, 7288, ..., 7224, 3159, 7400], dtype=int32),
#  array([2426, 3908, 7676, ..., 2986, 7334, 7103], dtype=int32),
#  array([1751, 6321, 7835, ..., 7430, 7167, 7932], dtype=int32),
#  array([3272, 1497, 2297, ..., 7459,  778, 1591], dtype=int32),
#  array([3322, 3492, 4524, ..., 6544, 4821,  988], dtype=int32),
#  array([3934, 6581, 7098, ..., 2115, 7467, 1265], dtype=int32),
#  array([3943, 6173, 4648, ..., 1276, 7596, 2999], dtype=int32),
#  array([4776,  418, 4567, ..., 5585, 2244,  790], dtype=int32),
#  array([5642,  729, 3580, ..., 1705, 5010, 1956], dtype=int32),
#  array([7234, 5940, 3961, ..., 7958,  595, 4021], dtype=int32),
#  array([2980, 5368, 4160, ..., 5031,  145, 7454], dtype=int32),
#  array([7848, 4199, 6486, ..., 7319,  382, 3977], dtype=int32),
#  array([1588, 4455, 4826, ..., 6895, 4085, 4978], dtype=int32),
#  array([1904, 2369, 1545, ..., 1376, 7211, 7225], dtype=int32),
#  array([ 684, 2707, 2329, ..., 7842, 1882, 3527], dtype=int32),
#  array([ 577, 7407, 2054, ..., 6955, 7816, 4443], dtype=int32),
#  array([5737, 6467,  934, ..., 1622, 4265, 7426], dtype=int32),
#  array([5343, 5405, 5708, ...,  878, 5278, 2890], dtype=int32),
#  array([ 738, 3929, 3752, ..., 5355, 6738,  489], dtype=int32),
#  array([5631,  112,  454, ..., 7676,  174, 7269], dtype=int32),
#  array([2545, 4004, 7937, ..., 7345, 1186, 7142], dtype=int32),
#  array([2343, 7790, 7137, ..., 7465, 5842, 2810], dtype=int32),
#  array([6092, 7736, 4696, ..., 3329, 2850, 5732], dtype=int32),
#  array([2620, 7831, 7908, ..., 5260, 2171, 1556], dtype=int32),
#  array([3710, 3461, 5355, ..., 4445, 2188, 3216], dtype=int32),
#  array([5930, 6213,  474, ..., 7437,  106,  826], dtype=int32),
#  array([7476, 1844, 2976, ..., 3973, 3246, 1504], dtype=int32),
#  array([5099, 1314, 1189, ..., 3997,  858, 1916], dtype=int32),
#  array([ 892, 6208, 7542, ...,  477, 6896, 4864], dtype=int32),
#  array([ 387, 4718, 5145, ..., 4448, 5738, 4493], dtype=int32),
#  array([2544, 2999, 6377, ..., 4787, 6421, 7665], dtype=int32),
#  array([ 157, 4262, 4672, ..., 1807, 4695, 2044], dtype=int32),
#  array([4634, 4245,  199, ..., 4227, 5912, 1280], dtype=int32),
#  array([5242, 7635,  776, ...,  161, 4903, 4111], dtype=int32),
#  array([4194, 5707, 7579, ..., 1059, 1279, 5996], dtype=int32),
#  array([7777, 3480, 7097, ..., 4474, 2268, 1971], dtype=int32),
#  array([ 829, 1975, 6271, ..., 1588, 2925, 5327], dtype=int32),
#  array([1428, 2402, 6073, ..., 5044, 2480, 2039], dtype=int32),
#  array([ 631,  224, 6454, ..., 7416, 2350, 3032], dtype=int32),
#  array([4232, 1870, 5935, ..., 1205, 3978,  187], dtype=int32),
#  array([7298, 4536, 5631, ..., 2371, 1019,  428], dtype=int32),
#  array([1844, 6708, 1254, ..., 3672, 1152, 6353], dtype=int32),
#  array([4160, 6682, 2265, ..., 2047, 4031, 2432], dtype=int32),
#  array([1253, 6565, 1143, ...,  798, 2250, 3005], dtype=int32),
#  array([7884,  235,  455, ..., 1642, 2630, 4594], dtype=int32),
#  array([2292, 2305,  372, ..., 4524, 6081, 3613], dtype=int32),
#  array([5317, 3166, 4160, ..., 4591, 5477,   89], dtype=int32),
#  array([ 677,  824, 7408, ..., 6194, 2195, 4182], dtype=int32),
#  array([5413, 7488, 4239, ...,  520, 6485, 5806], dtype=int32),
#  array([2099, 6687, 6654, ..., 5608, 6122, 1010], dtype=int32),
#  array([2124, 3582, 3852, ..., 1190, 5306, 1950], dtype=int32),
#  array([   1, 4145, 6848, ..., 5714, 6557, 6411], dtype=int32),
#  array([5894, 4554, 7117, ..., 4610, 4680, 3215], dtype=int32),
#  array([4705, 3719, 3104, ..., 2901, 5368, 5911], dtype=int32),
#  array([ 237, 4648, 4681, ..., 4237, 4643, 1950], dtype=int32),
#  array([ 977, 7386, 4370, ..., 3448, 4549, 7570], dtype=int32),
#  array([4839, 1069, 4785, ..., 7555, 1486, 1130], dtype=int32),
#  array([1920, 2074, 6520, ...,  824, 3692, 6057], dtype=int32),
#  array([4908, 5972, 3150, ..., 7834, 7992, 6610], dtype=int32),
#  array([4557, 7307,  233, ...,  309, 6074, 4211], dtype=int32),
#  array([3395, 4054,  221, ..., 1355, 7897, 2614], dtype=int32),
#  array([4221,  691, 3476, ..., 4035, 6466, 3046], dtype=int32),
#  array([1591, 3693, 4757, ..., 2291, 4822, 7813], dtype=int32),
#  array([1276, 7553, 6063, ..., 1402, 7051,  929], dtype=int32),
#  array([6816, 3930, 6492, ...,  694, 2389, 4421], dtype=int32),
#  array([7155, 5336, 6767, ..., 4632, 2028, 4540], dtype=int32),
#  array([1580, 2106, 3901, ..., 3823, 1521, 6102], dtype=int32),
#  array([2926, 4678, 7339, ...,  118, 4932, 3036], dtype=int32),
#  array([1019,  493, 7396, ..., 2997, 1213, 4012], dtype=int32),
#  array([6125, 4235, 2175, ..., 6565, 3802, 4699], dtype=int32),
#  array([2991, 3855, 3482, ..., 3144, 2140, 4828], dtype=int32),
#  array([5149, 7261, 4178, ..., 4659, 1123, 6385], dtype=int32),
#  array([1194, 2567, 3725, ...,  424, 5995, 2927], dtype=int32),
#  array([5105, 2741, 4967, ..., 4810,  886, 7368], dtype=int32),
#  array([4205, 5134, 3235, ..., 3433, 7643,   96], dtype=int32),
#  array([7379, 1585, 3584, ..., 6771, 4435, 5478], dtype=int32),
#  array([ 439, 5102, 2818, ...,  451, 3101, 5693], dtype=int32),
#  array([3884, 6528, 3288, ..., 4433, 3177, 5201], dtype=int32),
#  array([2447, 3097, 4355, ..., 4854, 5536, 1034], dtype=int32),
#  array([4352, 7998,  263, ..., 7462, 3474, 7894], dtype=int32),
#  array([2845, 4929, 6883, ...,  506,  554, 5318], dtype=int32),
#  array([ 708, 3078,  668, ..., 5336, 3091, 4643], dtype=int32),
#  array([1198, 4387, 2311, ..., 4727, 7465, 2678], dtype=int32),
#  array([6834, 2509,  653, ..., 5739, 1158, 7785], dtype=int32),
#  array([3635, 4170,  480, ..., 3009, 6187,  747], dtype=int32),
#  array([2374, 2945, 4968, ..., 2259, 6221, 1139], dtype=int32),
#  array([2113, 7272, 5441, ..., 2273, 3556,  592], dtype=int32),
#  array([2135, 6774, 5865, ..., 3345,  585, 2286], dtype=int32),
#  array([ 267, 2304, 3458, ..., 7751, 5073, 7387], dtype=int32),
#  array([ 294,  628, 3871, ..., 7423, 5913, 5439], dtype=int32),
#  array([5514, 4538, 5491, ..., 7679, 4157, 5811], dtype=int32),
#  array([4410, 1686, 7402, ..., 6605, 4473, 4012], dtype=int32),
#  array([5890, 2384, 6400, ...,  151, 3368, 2705], dtype=int32),
#  array([3575, 1910,  358, ..., 2105, 1733, 3678], dtype=int32),
#  array([ 889, 1967, 3443, ..., 2943, 6829, 1521], dtype=int32),
#  array([1133, 7628, 4299, ..., 5869, 5967, 6517], dtype=int32),
#  array([4209, 3798, 2940, ..., 2996, 2979, 3222], dtype=int32),
#  array([ 707, 1421, 4413, ..., 3176, 4940, 5258], dtype=int32),
#  array([ 698, 6949, 3385, ..., 1777, 4247, 4908], dtype=int32),
#  array([3306, 6121, 2120, ..., 4904, 1916,  205], dtype=int32),
#  array([3980, 1428, 5411, ..., 5962, 2850, 3148], dtype=int32),
#  array([7820, 2323, 1626, ..., 2555, 2188, 7577], dtype=int32),
#  array([2680, 1933, 1758, ..., 2783, 7275, 7741], dtype=int32),
#  array([1362, 4747, 1937, ..., 7082, 5923, 1599], dtype=int32),
#  array([7570,  870, 2934, ...,   54, 2086,  380], dtype=int32),
#  array([5742, 1298, 6491, ..., 4857, 4858, 4316], dtype=int32),
#  array([3263, 3219,  371, ..., 3590,  272, 7181], dtype=int32),
#  array([4072, 6184, 3861, ..., 4018, 3651,  668], dtype=int32),
#  array([6724,  286, 4110, ..., 6201, 5743,  926], dtype=int32),
#  array([ 964,  945, 1832, ..., 7949, 1033,  577], dtype=int32),
#  array([2990, 3796, 5946, ..., 1429, 5698, 3432], dtype=int32),
#  array([3797, 1877, 5056, ..., 3390, 3132, 1129], dtype=int32),
#  array([1076, 5145, 3154, ..., 3224, 7606, 4439], dtype=int32),
#  array([5317, 6485, 4767, ..., 6211, 6873, 7221], dtype=int32),
#  array([  64, 5163, 4287, ..., 3445,  951, 7160], dtype=int32),
#  array([3528, 3266,   26, ..., 6261, 7154, 6078], dtype=int32),
#  array([7289, 4572, 4051, ..., 2644,  573, 4627], dtype=int32),
#  array([2066, 5657, 7280, ..., 4691, 1782, 5861], dtype=int32),
#  array([2993, 3288, 3557, ..., 5970, 6345,  354], dtype=int32),
#  array([3550, 2900, 3203, ..., 4948,  914, 4347], dtype=int32),
#  array([7896,  272, 3153, ...,  828, 6166, 3381], dtype=int32),
#  array([4697, 1927, 5447, ..., 4137, 4851, 7983], dtype=int32),
#  array([5164, 7079,  347, ..., 3310,    3, 6531], dtype=int32),
#  array([5191, 3278, 5070, ..., 1890, 6267, 1123], dtype=int32),
#  array([7827, 7443, 1579, ..., 7618, 5540, 1416], dtype=int32),
#  array([6043, 1680, 6274, ..., 2252, 4830, 4511], dtype=int32),
#  array([3447, 5310, 4612, ..., 5906, 4985, 1777], dtype=int32),
#  array([7764,  535, 4483, ..., 1812, 1860, 7073], dtype=int32),
#  array([ 274, 5174, 1343, ..., 4841, 5321, 7339], dtype=int32),
#  array([1479, 3150, 6000, ...,   45, 6982,  302], dtype=int32),
#  array([7029, 3619, 5382, ..., 3390, 3914, 1803], dtype=int32),
#  array([5889, 5428, 1323, ..., 7670, 3856, 4264], dtype=int32),
#  array([7321,   24, 1171, ..., 7625,  148, 1513], dtype=int32),
#  array([ 281, 3702, 2365, ..., 3672, 7311, 4441], dtype=int32),
#  array([5887, 5043, 6170, ..., 6650, 7419, 5770], dtype=int32),
#  array([7607, 2815, 5407, ..., 5777, 2392, 6876], dtype=int32),
#  array([3306, 3601, 4380, ..., 6428, 4372, 1894], dtype=int32),
#  array([1219, 3152, 2004, ..., 2787, 7416, 1030], dtype=int32),
#  array([6365, 3222, 2098, ..., 5325, 5422, 1793], dtype=int32),
#  array([1636, 7815, 6324, ..., 7565, 3479, 5031], dtype=int32),
#  array([5466, 3335, 1081, ..., 4086, 7872, 7413], dtype=int32),
#  array([3294, 6589, 3473, ..., 1593, 4842, 7275], dtype=int32),
#  array([3612, 5927, 4950, ..., 5046,  682, 3731], dtype=int32),
#  array([2204, 7107, 3126, ..., 6176, 7969, 1531], dtype=int32),
#  array([5847, 3793, 6873, ..., 7120, 4936,  143], dtype=int32),
#  array([1453, 5307, 2570, ..., 6291, 5691, 6996], dtype=int32),
#  array([6753, 6665, 4947, ..., 3707, 1516, 6817], dtype=int32),
#  array([ 718, 3681, 7443, ..., 5723, 2341, 1900], dtype=int32),
#  array([5816, 3453, 5451, ..., 6704, 5209, 2475], dtype=int32),
#  array([5566, 6352, 2218, ..., 5777, 1680, 2806], dtype=int32),
#  array([1372, 1091, 2685, ..., 2896, 3445, 1113], dtype=int32),
#  array([4555, 3749, 5988, ..., 1191, 6623, 5780], dtype=int32),
#  array([3307, 4192, 1677, ..., 7144, 7794, 3940], dtype=int32),
#  array([5083, 2526, 1910, ..., 2907, 2807, 7489], dtype=int32),
#  array([3248, 4660, 5305, ..., 3257, 1929, 1411], dtype=int32),
#  array([2319, 7792, 3924, ..., 3448, 7710, 1404], dtype=int32),
#  array([ 665,  213, 6410, ..., 4023, 1901, 5409], dtype=int32),
#  array([2099, 4437, 4567, ...,  437, 4270, 5682], dtype=int32),
#  array([7322, 1991, 1078, ..., 3068,  947, 1630], dtype=int32),
#  array([3518, 4147, 2150, ..., 1425, 7642, 2507], dtype=int32),
#  array([7598,  886, 7158, ..., 3526, 7511, 7399], dtype=int32),
#  array([6601, 4458, 2621, ..., 7785, 7660, 2726], dtype=int32),
#  array([ 276, 5131, 6426, ..., 5934, 7169, 6956], dtype=int32),
#  array([5167, 4395, 2768, ..., 2392, 3626, 1230], dtype=int32),
#  array([4847, 1269, 1463, ..., 5787, 7491, 6181], dtype=int32),
#  array([6968, 6806, 6426, ..., 4752, 6065, 1357], dtype=int32),
#  array([2757, 7473, 5510, ..., 6631, 6513, 7730], dtype=int32),
#  array([5175, 7608, 3900, ..., 5618, 6072, 1094], dtype=int32),
#  array([1148, 5231,  502, ..., 7945, 7090, 4224], dtype=int32),
#  array([ 631, 7176, 7529, ..., 6286, 3342, 2659], dtype=int32),
#  array([2686, 7505, 7846, ..., 5712, 1296, 6401], dtype=int32),
#  array([3896, 7864, 6804, ..., 3850,  480, 6431], dtype=int32),
#  array([2663, 7565, 6991, ..., 3730, 3681, 1134], dtype=int32),
#  array([3374, 1341, 7528, ..., 7469, 6316, 2131], dtype=int32),
#  array([2718, 2629, 5524, ..., 6458, 5081, 6383], dtype=int32),
#  array([3186, 3193, 1386, ..., 6216, 4760,  493], dtype=int32),
#  array([4191, 6117, 4814, ..., 2772, 3837,  359], dtype=int32),
#  array([7049, 5132, 1595, ..., 4817, 5498, 1898], dtype=int32),
#  array([2330, 4441, 7580, ...,  907, 5534, 7862], dtype=int32),
#  array([6031,  203,  262, ..., 2528, 1688,  531], dtype=int32),
#  array([2805, 5233, 6452, ..., 6635, 1372, 4016], dtype=int32),
#  array([5165, 7045, 2957, ..., 1295, 5478, 1756], dtype=int32),
#  array([5112, 7664, 6298, ..., 2139, 5814, 3402], dtype=int32),
#  array([4823, 1044, 6336, ..., 4651, 7964, 4273], dtype=int32),
#  array([4025, 7015, 7665, ..., 6964,  220, 7523], dtype=int32),
#  array([2288, 1107, 6175, ..., 7305, 1697,  670], dtype=int32),
#  array([4181, 5380, 1506, ..., 5715, 5061, 1448], dtype=int32),
#  array([5908, 4236,  836, ..., 6310, 5942, 6621], dtype=int32),
#  array([3184, 2119, 3420, ..., 4045, 1016, 6476], dtype=int32),
#  array([6334, 1705, 2467, ...,  803, 7818, 4847], dtype=int32),
#  array([3068, 4831, 1880, ..., 4604, 6801, 2784], dtype=int32),
#  array([3951, 6721, 7576, ..., 5274, 1502, 2978], dtype=int32),
#  array([6577, 6176,  669, ..., 3906, 7541, 5165], dtype=int32),
#  array([6681, 2084, 4287, ..., 3591,  632, 3200], dtype=int32),
#  array([3054, 1476,  615, ..., 2512, 3807, 7843], dtype=int32),
#  array([4054,  618, 7599, ..., 7938, 4174, 2836], dtype=int32),
#  array([4242, 3724, 1749, ..., 6834, 7715, 5618], dtype=int32),
#  array([3199, 5027, 7058, ..., 5881, 3157, 6716], dtype=int32),
#  array([ 803, 4509, 6707, ..., 1770, 6311, 4472], dtype=int32),
#  array([4160, 2209, 6892, ..., 6131, 7606, 4684], dtype=int32),
#  array([2750, 1845, 7596, ..., 4905,  375,  583], dtype=int32),
#  array([4368, 3210, 3214, ..., 7531, 4138, 6041], dtype=int32),
#  array([4805, 1510,  816, ..., 7800, 7088,  539], dtype=int32),
#  array([7061,  846, 6692, ..., 7121, 2137, 6642], dtype=int32),
#  array([5401, 1563, 6213, ..., 7782, 2196, 1860], dtype=int32),
#  array([3399,  395, 5579, ..., 1005, 4913, 7669], dtype=int32),
#  array([4787, 3834, 5574, ...,  308, 2554, 5206], dtype=int32),
#  array([6165, 5745, 2528, ..., 4507,  203, 6642], dtype=int32),
#  array([5257, 7855, 4574, ..., 1532, 6114, 1238], dtype=int32),
#  array([6060, 3721, 2992, ..., 2889, 6692,  334], dtype=int32),
#  array([7838, 4581, 3919, ..., 1325,  736, 1681], dtype=int32),
#  array([6898, 1109, 3786, ..., 7180, 1421, 7130], dtype=int32),
#  array([5702, 5602, 3340, ..., 3061, 6151, 5620], dtype=int32),
#  array([1381, 4901, 4821, ..., 5727,  266, 1879], dtype=int32),
#  array([7316, 7449, 6300, ..., 7804, 3730, 2026], dtype=int32),
#  array([1062, 4049, 4432, ..., 7288, 2812, 1426], dtype=int32),
#  array([1608, 1412,  685, ...,   84, 2922, 6077], dtype=int32),
#  array([ 818,   10, 1350, ..., 7919,  555, 4524], dtype=int32),
#  array([7768, 7159, 2207, ..., 2248, 6556, 6893], dtype=int32),
#  array([2509, 2781, 2560, ..., 6978,  981, 7551], dtype=int32),
#  array([4995, 3835,  486, ..., 3227, 1576, 1627], dtype=int32),
#  array([6893, 4042, 2403, ...,  513, 5829,  469], dtype=int32),
#  array([5618, 4513, 4633, ..., 2797, 7343, 1552], dtype=int32),
#  array([3101, 5041, 7275, ..., 6145, 3434, 1960], dtype=int32),
#  array([7757, 4031, 1941, ..., 2809, 5766, 7046], dtype=int32),
#  array([ 937, 1337, 4852, ..., 1908, 6589, 7875], dtype=int32),
#  array([4135, 3353, 6694, ..., 1653, 7044, 3401], dtype=int32),
#  array([1002, 4557, 6595, ..., 7488, 2381, 1940], dtype=int32),
#  array([3853, 5425, 2074, ..., 3857, 7264, 3270], dtype=int32),
#  array([5042, 5567, 7436, ...,  708, 2632, 1010], dtype=int32),
#  array([3244, 3557, 6541, ..., 3078,   59, 6924], dtype=int32),
#  array([4597, 2467, 1808, ..., 3509,  367, 6309], dtype=int32),
#  array([3267, 1224,  261, ..., 5768, 6400, 4543], dtype=int32),
#  array([5335, 3215, 7341, ..., 6630, 5449, 7198], dtype=int32),
#  array([4130, 6504,  369, ..., 3484, 2284, 3741], dtype=int32),
#  array([3826,  810, 5285, ..., 6175, 6016, 7071], dtype=int32),
#  array([1411, 1515, 1065, ...,   48, 5954, 7877], dtype=int32),
#  array([4858, 7504, 6786, ..., 3687, 2935, 1855], dtype=int32),
#  array([5754,  349, 3652, ..., 1667, 7454, 5084], dtype=int32)]

# %%
bag.estimators_features_
# Out:
# [array([3, 3, 4, 2, 9], dtype=int32),
#  array([1, 4, 7, 6, 6], dtype=int32),
#  array([0, 2, 8, 7, 4], dtype=int32),
#  array([9, 1, 0, 1, 9], dtype=int32),
#  array([5, 6, 8, 6, 2], dtype=int32),
#  array([6, 2, 1, 9, 6], dtype=int32),
#  array([2, 2, 7, 6, 3], dtype=int32),
#  array([1, 6, 1, 0, 4], dtype=int32),
#  array([8, 3, 5, 7, 1], dtype=int32),
#  array([5, 1, 0, 4, 9], dtype=int32),
#  array([3, 5, 6, 9, 3], dtype=int32),
#  array([0, 1, 0, 4, 8], dtype=int32),
#  array([4, 9, 1, 8, 6], dtype=int32),
#  array([0, 7, 7, 5, 4], dtype=int32),
#  array([0, 0, 4, 2, 2], dtype=int32),
#  array([0, 7, 9, 2, 0], dtype=int32),
#  array([1, 4, 1, 3, 1], dtype=int32),
#  array([3, 0, 6, 7, 6], dtype=int32),
#  array([7, 3, 6, 4, 4], dtype=int32),
#  array([0, 5, 9, 1, 9], dtype=int32),
#  array([8, 7, 5, 6, 6], dtype=int32),
#  array([7, 7, 9, 1, 8], dtype=int32),
#  array([1, 7, 1, 8, 2], dtype=int32),
#  array([6, 8, 1, 5, 2], dtype=int32),
#  array([4, 8, 4, 1, 6], dtype=int32),
#  array([1, 7, 3, 3, 6], dtype=int32),
#  array([8, 7, 9, 9, 3], dtype=int32),
#  array([8, 7, 2, 1, 8], dtype=int32),
#  array([2, 1, 3, 6, 4], dtype=int32),
#  array([8, 7, 5, 6, 7], dtype=int32),
#  array([7, 7, 8, 8, 8], dtype=int32),
#  array([4, 6, 5, 4, 2], dtype=int32),
#  array([5, 5, 4, 0, 2], dtype=int32),
#  array([2, 2, 9, 5, 3], dtype=int32),
#  array([0, 9, 1, 2, 4], dtype=int32),
#  array([7, 3, 0, 1, 0], dtype=int32),
#  array([9, 6, 1, 5, 5], dtype=int32),
#  array([4, 0, 6, 0, 1], dtype=int32),
#  array([9, 6, 4, 6, 3], dtype=int32),
#  array([9, 9, 3, 8, 4], dtype=int32),
#  array([0, 9, 6, 8, 5], dtype=int32),
#  array([6, 7, 9, 9, 5], dtype=int32),
#  array([0, 2, 6, 5, 4], dtype=int32),
#  array([0, 7, 9, 0, 6], dtype=int32),
#  array([1, 3, 2, 7, 1], dtype=int32),
#  array([4, 2, 8, 8, 7], dtype=int32),
#  array([2, 2, 8, 6, 8], dtype=int32),
#  array([5, 2, 0, 6, 8], dtype=int32),
#  array([9, 2, 9, 0, 0], dtype=int32),
#  array([5, 6, 6, 2, 6], dtype=int32),
#  array([1, 7, 6, 4, 0], dtype=int32),
#  array([7, 9, 7, 6, 7], dtype=int32),
#  array([1, 2, 1, 3, 4], dtype=int32),
#  array([7, 9, 1, 3, 7], dtype=int32),
#  array([2, 2, 1, 8, 6], dtype=int32),
#  array([5, 3, 3, 4, 8], dtype=int32),
#  array([6, 4, 1, 8, 1], dtype=int32),
#  array([2, 0, 0, 5, 2], dtype=int32),
#  array([1, 6, 9, 3, 6], dtype=int32),
#  array([5, 3, 1, 3, 7], dtype=int32),
#  array([0, 7, 1, 9, 8], dtype=int32),
#  array([9, 8, 8, 2, 0], dtype=int32),
#  array([4, 6, 8, 3, 7], dtype=int32),
#  array([0, 7, 4, 6, 7], dtype=int32),
#  array([6, 6, 2, 9, 5], dtype=int32),
#  array([7, 8, 3, 9, 4], dtype=int32),
#  array([1, 8, 3, 2, 6], dtype=int32),
#  array([1, 1, 4, 0, 1], dtype=int32),
#  array([5, 6, 9, 3, 3], dtype=int32),
#  array([5, 5, 0, 1, 3], dtype=int32),
#  array([9, 4, 3, 9, 0], dtype=int32),
#  array([3, 9, 1, 1, 6], dtype=int32),
#  array([5, 7, 9, 5, 8], dtype=int32),
#  array([9, 3, 3, 9, 3], dtype=int32),
#  array([1, 4, 6, 0, 4], dtype=int32),
#  array([9, 1, 3, 3, 8], dtype=int32),
#  array([5, 5, 3, 4, 7], dtype=int32),
#  array([5, 7, 0, 3, 4], dtype=int32),
#  array([5, 3, 1, 3, 4], dtype=int32),
#  array([9, 2, 9, 6, 7], dtype=int32),
#  array([7, 9, 7, 9, 5], dtype=int32),
#  array([5, 8, 9, 7, 2], dtype=int32),
#  array([2, 6, 3, 1, 4], dtype=int32),
#  array([1, 1, 6, 6, 5], dtype=int32),
#  array([5, 5, 6, 7, 9], dtype=int32),
#  array([1, 9, 9, 5, 1], dtype=int32),
#  array([8, 2, 8, 6, 2], dtype=int32),
#  array([1, 6, 9, 3, 6], dtype=int32),
#  array([3, 5, 1, 8, 7], dtype=int32),
#  array([2, 1, 2, 2, 3], dtype=int32),
#  array([5, 9, 7, 8, 8], dtype=int32),
#  array([2, 3, 8, 5, 0], dtype=int32),
#  array([3, 9, 0, 2, 9], dtype=int32),
#  array([8, 4, 8, 3, 8], dtype=int32),
#  array([2, 5, 9, 3, 3], dtype=int32),
#  array([0, 9, 2, 4, 9], dtype=int32),
#  array([4, 8, 9, 4, 3], dtype=int32),
#  array([6, 7, 4, 8, 5], dtype=int32),
#  array([5, 4, 3, 4, 1], dtype=int32),
#  array([9, 2, 3, 0, 4], dtype=int32),
#  array([2, 3, 2, 5, 3], dtype=int32),
#  array([8, 9, 8, 4, 2], dtype=int32),
#  array([6, 2, 4, 7, 2], dtype=int32),
#  array([8, 6, 5, 3, 1], dtype=int32),
#  array([5, 9, 6, 2, 3], dtype=int32),
#  array([0, 3, 7, 3, 2], dtype=int32),
#  array([5, 4, 9, 6, 5], dtype=int32),
#  array([5, 2, 5, 9, 8], dtype=int32),
#  array([4, 0, 0, 9, 7], dtype=int32),
#  array([0, 0, 0, 3, 4], dtype=int32),
#  array([0, 3, 4, 4, 4], dtype=int32),
#  array([5, 9, 3, 8, 8], dtype=int32),
#  array([5, 2, 1, 0, 9], dtype=int32),
#  array([4, 3, 2, 7, 5], dtype=int32),
#  array([9, 1, 4, 7, 7], dtype=int32),
#  array([8, 6, 9, 8, 3], dtype=int32),
#  array([5, 7, 9, 0, 4], dtype=int32),
#  array([7, 2, 6, 5, 3], dtype=int32),
#  array([3, 5, 8, 5, 0], dtype=int32),
#  array([0, 1, 7, 6, 5], dtype=int32),
#  array([7, 7, 9, 1, 2], dtype=int32),
#  array([3, 4, 5, 1, 4], dtype=int32),
#  array([7, 5, 1, 4, 8], dtype=int32),
#  array([2, 4, 3, 1, 0], dtype=int32),
#  array([0, 6, 8, 3, 2], dtype=int32),
#  array([2, 9, 9, 2, 5], dtype=int32),
#  array([1, 1, 7, 1, 1], dtype=int32),
#  array([0, 1, 5, 6, 1], dtype=int32),
#  array([7, 9, 9, 7, 9], dtype=int32),
#  array([6, 7, 1, 8, 8], dtype=int32),
#  array([1, 1, 0, 7, 5], dtype=int32),
#  array([0, 5, 3, 4, 5], dtype=int32),
#  array([3, 2, 6, 0, 1], dtype=int32),
#  array([5, 4, 0, 1, 5], dtype=int32),
#  array([4, 7, 8, 4, 5], dtype=int32),
#  array([9, 0, 2, 4, 0], dtype=int32),
#  array([6, 8, 6, 0, 0], dtype=int32),
#  array([5, 8, 5, 2, 6], dtype=int32),
#  array([8, 4, 5, 0, 3], dtype=int32),
#  array([6, 4, 8, 0, 8], dtype=int32),
#  array([3, 7, 4, 0, 6], dtype=int32),
#  array([3, 2, 4, 2, 9], dtype=int32),
#  array([3, 8, 7, 5, 2], dtype=int32),
#  array([6, 2, 9, 1, 9], dtype=int32),
#  array([7, 2, 4, 5, 5], dtype=int32),
#  array([3, 5, 7, 9, 7], dtype=int32),
#  array([3, 6, 8, 8, 5], dtype=int32),
#  array([9, 2, 9, 3, 6], dtype=int32),
#  array([6, 3, 2, 9, 9], dtype=int32),
#  array([8, 9, 1, 8, 0], dtype=int32),
#  array([2, 8, 2, 5, 4], dtype=int32),
#  array([5, 1, 9, 0, 4], dtype=int32),
#  array([9, 0, 9, 3, 9], dtype=int32),
#  array([6, 5, 4, 0, 9], dtype=int32),
#  array([4, 7, 2, 6, 4], dtype=int32),
#  array([7, 8, 4, 4, 4], dtype=int32),
#  array([3, 3, 7, 4, 5], dtype=int32),
#  array([4, 3, 4, 4, 4], dtype=int32),
#  array([9, 7, 7, 1, 7], dtype=int32),
#  array([5, 2, 3, 5, 8], dtype=int32),
#  array([3, 2, 4, 9, 3], dtype=int32),
#  array([6, 0, 0, 7, 6], dtype=int32),
#  array([9, 4, 6, 4, 2], dtype=int32),
#  array([0, 7, 8, 7, 3], dtype=int32),
#  array([6, 5, 1, 0, 8], dtype=int32),
#  array([1, 0, 9, 0, 9], dtype=int32),
#  array([5, 1, 2, 6, 7], dtype=int32),
#  array([5, 6, 1, 8, 9], dtype=int32),
#  array([9, 8, 4, 1, 5], dtype=int32),
#  array([9, 8, 1, 2, 2], dtype=int32),
#  array([5, 7, 4, 3, 8], dtype=int32),
#  array([7, 1, 1, 5, 4], dtype=int32),
#  array([1, 3, 4, 3, 1], dtype=int32),
#  array([3, 6, 7, 8, 0], dtype=int32),
#  array([3, 5, 5, 4, 1], dtype=int32),
#  array([4, 8, 2, 1, 3], dtype=int32),
#  array([6, 5, 7, 4, 2], dtype=int32),
#  array([1, 8, 1, 0, 4], dtype=int32),
#  array([1, 5, 6, 1, 4], dtype=int32),
#  array([1, 4, 8, 1, 4], dtype=int32),
#  array([8, 3, 1, 2, 4], dtype=int32),
#  array([6, 4, 0, 5, 5], dtype=int32),
#  array([6, 3, 3, 8, 8], dtype=int32),
#  array([6, 8, 3, 5, 0], dtype=int32),
#  array([6, 3, 3, 0, 9], dtype=int32),
#  array([9, 2, 2, 2, 9], dtype=int32),
#  array([8, 0, 5, 4, 3], dtype=int32),
#  array([9, 5, 7, 8, 0], dtype=int32),
#  array([4, 7, 3, 9, 6], dtype=int32),
#  array([1, 0, 4, 8, 7], dtype=int32),
#  array([8, 2, 0, 6, 8], dtype=int32),
#  array([0, 0, 2, 4, 9], dtype=int32),
#  array([2, 2, 6, 4, 6], dtype=int32),
#  array([0, 0, 9, 6, 2], dtype=int32),
#  array([1, 8, 1, 9, 4], dtype=int32),
#  array([3, 7, 1, 1, 7], dtype=int32),
#  array([2, 2, 1, 4, 0], dtype=int32),
#  array([9, 5, 1, 9, 6], dtype=int32),
#  array([2, 4, 7, 5, 3], dtype=int32),
#  array([7, 5, 0, 5, 5], dtype=int32),
#  array([2, 6, 7, 2, 1], dtype=int32),
#  array([6, 6, 5, 7, 2], dtype=int32),
#  array([5, 4, 0, 5, 2], dtype=int32),
#  array([5, 3, 6, 4, 4], dtype=int32),
#  array([0, 6, 8, 0, 1], dtype=int32),
#  array([7, 0, 7, 0, 2], dtype=int32),
#  array([0, 4, 1, 4, 2], dtype=int32),
#  array([3, 5, 3, 2, 4], dtype=int32),
#  array([7, 7, 4, 0, 4], dtype=int32),
#  array([4, 3, 3, 0, 4], dtype=int32),
#  array([2, 2, 5, 0, 8], dtype=int32),
#  array([2, 3, 1, 7, 3], dtype=int32),
#  array([8, 3, 6, 4, 6], dtype=int32),
#  array([0, 9, 2, 2, 6], dtype=int32),
#  array([9, 7, 6, 4, 4], dtype=int32),
#  array([3, 1, 9, 9, 7], dtype=int32),
#  array([8, 7, 7, 5, 7], dtype=int32),
#  array([5, 9, 8, 6, 8], dtype=int32),
#  array([8, 2, 1, 2, 6], dtype=int32),
#  array([9, 2, 1, 2, 1], dtype=int32),
#  array([4, 4, 3, 7, 3], dtype=int32),
#  array([3, 6, 8, 6, 7], dtype=int32),
#  array([9, 8, 4, 1, 1], dtype=int32),
#  array([6, 2, 7, 9, 9], dtype=int32),
#  array([0, 8, 1, 3, 2], dtype=int32),
#  array([3, 0, 2, 3, 2], dtype=int32),
#  array([3, 0, 2, 3, 8], dtype=int32),
#  array([7, 2, 6, 1, 3], dtype=int32),
#  array([6, 3, 9, 3, 3], dtype=int32),
#  array([6, 5, 0, 6, 3], dtype=int32),
#  array([0, 4, 6, 6, 8], dtype=int32),
#  array([1, 4, 0, 5, 0], dtype=int32),
#  array([5, 0, 4, 8, 2], dtype=int32),
#  array([1, 9, 5, 2, 7], dtype=int32),
#  array([9, 4, 1, 4, 9], dtype=int32),
#  array([7, 3, 2, 5, 3], dtype=int32),
#  array([6, 3, 1, 4, 3], dtype=int32),
#  array([2, 1, 1, 9, 4], dtype=int32),
#  array([3, 7, 6, 5, 6], dtype=int32),
#  array([7, 7, 5, 3, 4], dtype=int32),
#  array([7, 3, 0, 1, 4], dtype=int32),
#  array([3, 8, 2, 2, 2], dtype=int32),
#  array([8, 4, 7, 5, 0], dtype=int32),
#  array([0, 6, 1, 6, 2], dtype=int32),
#  array([3, 5, 5, 1, 3], dtype=int32),
#  array([9, 5, 6, 5, 2], dtype=int32),
#  array([9, 3, 1, 8, 6], dtype=int32),
#  array([8, 2, 0, 3, 9], dtype=int32),
#  array([7, 9, 5, 6, 1], dtype=int32),
#  array([7, 2, 9, 9, 8], dtype=int32),
#  array([2, 8, 6, 1, 2], dtype=int32),
#  array([6, 4, 1, 3, 2], dtype=int32),
#  array([4, 1, 2, 3, 6], dtype=int32),
#  array([5, 2, 3, 3, 2], dtype=int32),
#  array([4, 9, 0, 7, 4], dtype=int32),
#  array([3, 8, 4, 8, 7], dtype=int32),
#  array([3, 5, 0, 5, 7], dtype=int32),
#  array([9, 5, 8, 1, 7], dtype=int32),
#  array([7, 6, 0, 6, 5], dtype=int32),
#  array([9, 3, 8, 5, 4], dtype=int32),
#  array([1, 0, 9, 6, 0], dtype=int32),
#  array([1, 8, 5, 6, 9], dtype=int32),
#  array([1, 8, 0, 7, 6], dtype=int32),
#  array([5, 1, 8, 2, 0], dtype=int32),
#  array([1, 5, 7, 7, 6], dtype=int32),
#  array([7, 2, 0, 7, 8], dtype=int32),
#  array([0, 3, 9, 0, 6], dtype=int32),
#  array([4, 9, 7, 2, 6], dtype=int32),
#  array([1, 1, 8, 8, 6], dtype=int32),
#  array([4, 5, 8, 7, 6], dtype=int32),
#  array([2, 0, 1, 4, 0], dtype=int32),
#  array([9, 7, 6, 8, 1], dtype=int32),
#  array([2, 3, 0, 0, 7], dtype=int32),
#  array([3, 0, 4, 6, 5], dtype=int32),
#  array([3, 7, 4, 2, 6], dtype=int32),
#  array([7, 5, 2, 2, 1], dtype=int32),
#  array([7, 8, 0, 5, 4], dtype=int32),
#  array([4, 2, 1, 9, 7], dtype=int32),
#  array([6, 9, 7, 7, 4], dtype=int32),
#  array([6, 5, 5, 4, 4], dtype=int32),
#  array([5, 0, 0, 7, 1], dtype=int32),
#  array([7, 5, 0, 3, 2], dtype=int32),
#  array([5, 6, 2, 6, 8], dtype=int32),
#  array([9, 1, 5, 2, 9], dtype=int32),
#  array([9, 9, 1, 6, 6], dtype=int32),
#  array([4, 8, 0, 8, 8], dtype=int32),
#  array([4, 5, 9, 6, 4], dtype=int32),
#  array([0, 1, 3, 0, 2], dtype=int32),
#  array([0, 2, 0, 8, 3], dtype=int32),
#  array([0, 5, 9, 4, 3], dtype=int32),
#  array([5, 1, 5, 6, 6], dtype=int32),
#  array([7, 8, 6, 6, 5], dtype=int32),
#  array([9, 5, 8, 0, 7], dtype=int32),
#  array([2, 0, 5, 0, 2], dtype=int32),
#  array([7, 5, 4, 6, 0], dtype=int32),
#  array([7, 7, 9, 3, 7], dtype=int32),
#  array([8, 9, 1, 0, 5], dtype=int32),
#  array([6, 7, 3, 9, 2], dtype=int32),
#  array([2, 9, 6, 6, 6], dtype=int32),
#  array([2, 2, 9, 8, 1], dtype=int32),
#  array([1, 0, 1, 5, 5], dtype=int32),
#  array([9, 9, 2, 8, 2], dtype=int32),
#  array([5, 6, 7, 6, 4], dtype=int32),
#  array([1, 7, 3, 3, 8], dtype=int32),
#  array([7, 4, 4, 2, 1], dtype=int32),
#  array([3, 6, 2, 2, 0], dtype=int32),
#  array([5, 8, 4, 3, 5], dtype=int32),
#  array([5, 0, 6, 0, 0], dtype=int32),
#  array([1, 4, 9, 6, 3], dtype=int32),
#  array([4, 4, 5, 8, 2], dtype=int32),
#  array([1, 6, 2, 9, 4], dtype=int32),
#  array([3, 3, 8, 6, 1], dtype=int32),
#  array([4, 7, 2, 5, 2], dtype=int32),
#  array([9, 9, 0, 0, 2], dtype=int32),
#  array([1, 1, 3, 2, 0], dtype=int32),
#  array([6, 1, 3, 9, 3], dtype=int32),
#  array([5, 5, 1, 0, 3], dtype=int32),
#  array([6, 3, 1, 0, 7], dtype=int32),
#  array([4, 6, 4, 8, 5], dtype=int32),
#  array([3, 3, 4, 2, 8], dtype=int32),
#  array([1, 3, 5, 7, 7], dtype=int32),
#  array([9, 9, 3, 1, 3], dtype=int32),
#  array([6, 9, 4, 4, 9], dtype=int32),
#  array([0, 9, 2, 8, 0], dtype=int32),
#  array([2, 9, 0, 7, 1], dtype=int32),
#  array([8, 2, 5, 1, 2], dtype=int32),
#  array([8, 2, 2, 7, 9], dtype=int32),
#  array([5, 5, 0, 1, 5], dtype=int32),
#  array([9, 5, 5, 2, 4], dtype=int32),
#  array([4, 2, 2, 4, 1], dtype=int32),
#  array([0, 1, 9, 5, 7], dtype=int32),
#  array([3, 6, 8, 9, 0], dtype=int32),
#  array([9, 7, 1, 0, 8], dtype=int32),
#  array([1, 9, 1, 0, 1], dtype=int32),
#  array([9, 4, 4, 1, 6], dtype=int32),
#  array([4, 5, 0, 7, 5], dtype=int32),
#  array([1, 8, 9, 1, 5], dtype=int32),
#  array([6, 3, 5, 1, 0], dtype=int32),
#  array([1, 3, 7, 6, 1], dtype=int32),
#  array([9, 1, 9, 8, 2], dtype=int32),
#  array([9, 6, 6, 1, 9], dtype=int32),
#  array([4, 2, 3, 6, 8], dtype=int32),
#  array([6, 0, 0, 3, 7], dtype=int32),
#  array([2, 1, 4, 6, 3], dtype=int32),
#  array([5, 1, 1, 6, 7], dtype=int32),
#  array([4, 4, 2, 0, 4], dtype=int32),
#  array([2, 8, 8, 5, 3], dtype=int32),
#  array([8, 4, 3, 1, 3], dtype=int32),
#  array([2, 7, 6, 0, 8], dtype=int32),
#  array([0, 9, 1, 9, 3], dtype=int32),
#  array([5, 9, 3, 3, 7], dtype=int32),
#  array([4, 6, 0, 8, 1], dtype=int32),
#  array([8, 4, 2, 8, 1], dtype=int32),
#  array([8, 1, 2, 4, 6], dtype=int32),
#  array([1, 3, 3, 6, 3], dtype=int32),
#  array([1, 4, 0, 4, 6], dtype=int32),
#  array([7, 0, 4, 6, 8], dtype=int32),
#  array([1, 4, 9, 2, 6], dtype=int32),
#  array([8, 2, 5, 2, 5], dtype=int32),
#  array([6, 8, 4, 6, 5], dtype=int32),
#  array([1, 8, 7, 1, 9], dtype=int32),
#  array([0, 0, 0, 7, 7], dtype=int32),
#  array([4, 0, 1, 9, 6], dtype=int32),
#  array([3, 1, 3, 4, 4], dtype=int32),
#  array([9, 1, 9, 6, 9], dtype=int32),
#  array([8, 1, 6, 0, 9], dtype=int32),
#  array([1, 1, 3, 1, 7], dtype=int32),
#  array([6, 4, 2, 2, 1], dtype=int32),
#  array([1, 9, 9, 4, 1], dtype=int32),
#  array([0, 5, 7, 3, 1], dtype=int32),
#  array([3, 4, 6, 6, 3], dtype=int32),
#  array([9, 5, 2, 9, 5], dtype=int32),
#  array([6, 5, 1, 9, 8], dtype=int32),
#  array([0, 5, 1, 2, 3], dtype=int32),
#  array([1, 9, 8, 5, 5], dtype=int32),
#  array([6, 0, 5, 1, 1], dtype=int32),
#  array([0, 3, 5, 0, 9], dtype=int32),
#  array([6, 7, 3, 7, 1], dtype=int32),
#  array([4, 6, 7, 0, 3], dtype=int32),
#  array([3, 3, 7, 5, 9], dtype=int32),
#  array([7, 2, 2, 5, 1], dtype=int32),
#  array([9, 5, 5, 6, 4], dtype=int32),
#  array([9, 8, 6, 2, 4], dtype=int32),
#  array([2, 0, 7, 1, 8], dtype=int32),
#  array([2, 0, 7, 1, 7], dtype=int32),
#  array([9, 5, 0, 5, 1], dtype=int32),
#  array([6, 4, 9, 9, 2], dtype=int32),
#  array([8, 4, 3, 1, 3], dtype=int32),
#  array([1, 4, 3, 2, 3], dtype=int32),
#  array([4, 5, 8, 5, 6], dtype=int32),
#  array([6, 0, 7, 7, 6], dtype=int32),
#  array([3, 6, 8, 6, 4], dtype=int32),
#  array([7, 3, 3, 4, 6], dtype=int32),
#  array([7, 4, 6, 7, 6], dtype=int32),
#  array([2, 8, 2, 1, 6], dtype=int32),
#  array([4, 8, 6, 7, 5], dtype=int32),
#  array([1, 9, 4, 3, 6], dtype=int32),
#  array([8, 1, 8, 7, 3], dtype=int32),
#  array([3, 6, 9, 4, 7], dtype=int32),
#  array([3, 6, 2, 6, 2], dtype=int32),
#  array([8, 8, 7, 5, 3], dtype=int32),
#  array([0, 5, 2, 8, 1], dtype=int32),
#  array([8, 6, 0, 6, 8], dtype=int32),
#  array([8, 2, 8, 1, 7], dtype=int32),
#  array([6, 3, 1, 4, 8], dtype=int32),
#  array([8, 6, 8, 4, 7], dtype=int32),
#  array([1, 2, 5, 0, 3], dtype=int32),
#  array([2, 5, 2, 2, 7], dtype=int32),
#  array([5, 8, 4, 1, 9], dtype=int32),
#  array([1, 8, 1, 3, 3], dtype=int32),
#  array([1, 2, 0, 0, 6], dtype=int32),
#  array([1, 8, 1, 4, 8], dtype=int32),
#  array([2, 6, 4, 3, 1], dtype=int32),
#  array([0, 7, 1, 0, 1], dtype=int32),
#  array([4, 5, 5, 7, 2], dtype=int32),
#  array([8, 3, 4, 1, 2], dtype=int32),
#  array([5, 6, 5, 2, 9], dtype=int32),
#  array([3, 7, 9, 5, 9], dtype=int32),
#  array([6, 8, 5, 6, 3], dtype=int32),
#  array([3, 6, 6, 1, 3], dtype=int32),
#  array([5, 3, 1, 6, 0], dtype=int32),
#  array([0, 8, 7, 9, 5], dtype=int32),
#  array([4, 1, 3, 2, 3], dtype=int32),
#  array([9, 4, 0, 3, 9], dtype=int32),
#  array([2, 3, 6, 3, 2], dtype=int32),
#  array([5, 9, 1, 9, 4], dtype=int32),
#  array([9, 5, 7, 9, 8], dtype=int32),
#  array([6, 4, 1, 4, 1], dtype=int32),
#  array([5, 6, 8, 2, 7], dtype=int32),
#  array([4, 2, 9, 1, 0], dtype=int32),
#  array([9, 3, 8, 7, 3], dtype=int32),
#  array([7, 8, 5, 8, 9], dtype=int32),
#  array([6, 1, 2, 6, 7], dtype=int32),
#  array([7, 0, 1, 4, 9], dtype=int32),
#  array([4, 5, 3, 5, 3], dtype=int32),
#  array([1, 7, 9, 9, 5], dtype=int32),
#  array([7, 9, 4, 8, 2], dtype=int32),
#  array([0, 9, 0, 2, 0], dtype=int32),
#  array([9, 2, 6, 2, 7], dtype=int32),
#  array([5, 1, 0, 4, 2], dtype=int32),
#  array([6, 3, 9, 7, 4], dtype=int32),
#  array([4, 6, 8, 3, 2], dtype=int32),
#  array([6, 6, 1, 5, 8], dtype=int32),
#  array([7, 1, 7, 4, 4], dtype=int32),
#  array([0, 9, 7, 4, 7], dtype=int32),
#  array([3, 6, 3, 2, 6], dtype=int32),
#  array([5, 9, 8, 8, 0], dtype=int32),
#  array([9, 7, 4, 7, 5], dtype=int32),
#  array([7, 5, 8, 5, 2], dtype=int32),
#  array([3, 9, 7, 8, 9], dtype=int32),
#  array([0, 7, 8, 4, 5], dtype=int32),
#  array([0, 0, 7, 4, 7], dtype=int32),
#  array([2, 4, 9, 9, 7], dtype=int32),
#  array([7, 1, 8, 6, 5], dtype=int32),
#  array([3, 0, 9, 7, 2], dtype=int32),
#  array([8, 3, 2, 8, 0], dtype=int32),
#  array([3, 4, 0, 9, 2], dtype=int32),
#  array([3, 2, 7, 2, 5], dtype=int32),
#  array([1, 1, 0, 9, 0], dtype=int32),
#  array([7, 5, 5, 5, 7], dtype=int32),
#  array([0, 8, 4, 9, 2], dtype=int32),
#  array([0, 1, 7, 4, 5], dtype=int32),
#  array([2, 3, 1, 5, 2], dtype=int32),
#  array([8, 2, 4, 9, 4], dtype=int32),
#  array([1, 3, 1, 9, 4], dtype=int32),
#  array([8, 5, 7, 8, 1], dtype=int32),
#  array([1, 7, 5, 2, 3], dtype=int32),
#  array([1, 7, 1, 7, 2], dtype=int32),
#  array([6, 7, 1, 5, 6], dtype=int32),
#  array([3, 8, 7, 5, 8], dtype=int32),
#  array([6, 8, 3, 8, 8], dtype=int32),
#  array([0, 8, 0, 3, 9], dtype=int32),
#  array([7, 0, 0, 1, 4], dtype=int32),
#  array([5, 5, 1, 7, 8], dtype=int32),
#  array([9, 9, 4, 2, 0], dtype=int32),
#  array([2, 3, 7, 1, 6], dtype=int32),
#  array([8, 3, 3, 8, 5], dtype=int32),
#  array([1, 0, 4, 7, 8], dtype=int32),
#  array([0, 2, 1, 9, 5], dtype=int32),
#  array([9, 7, 5, 5, 8], dtype=int32),
#  array([2, 5, 0, 7, 6], dtype=int32),
#  array([4, 6, 6, 2, 8], dtype=int32),
#  array([5, 8, 7, 4, 3], dtype=int32),
#  array([7, 4, 9, 5, 8], dtype=int32),
#  array([8, 7, 9, 1, 2], dtype=int32),
#  array([2, 6, 6, 8, 2], dtype=int32),
#  array([5, 4, 0, 0, 0], dtype=int32),
#  array([3, 5, 0, 2, 9], dtype=int32),
#  array([6, 4, 1, 8, 1], dtype=int32),
#  array([4, 5, 2, 6, 4], dtype=int32),
#  array([7, 0, 0, 1, 7], dtype=int32),
#  array([3, 4, 3, 3, 7], dtype=int32),
#  array([7, 7, 5, 1, 7], dtype=int32),
#  array([4, 8, 8, 4, 1], dtype=int32),
#  array([8, 6, 2, 7, 9], dtype=int32),
#  array([4, 8, 4, 1, 7], dtype=int32),
#  array([2, 8, 4, 4, 6], dtype=int32),
#  array([6, 5, 5, 2, 8], dtype=int32),
#  array([2, 6, 8, 4, 5], dtype=int32),
#  array([4, 7, 1, 4, 3], dtype=int32)]

# %% [markdown]
# ## 5. OOB Score

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.5,
    bootstrap=True,
    oob_score=True,
    random_state=2

)
bag.fit(X_train, y_train)
y_pred = bag.predict(X_test)
print('OOB score: ', bag.oob_score_)
print('Accuracy score: ', accuracy_score(y_test, y_pred))
# Out:
# OOB score:  0.898625
# Accuracy score:  0.9115

# %% [markdown]
# ## Applying Grid search CV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
parameters = {
    # 'estimators': [
    #     DecisionTreeClassifier(),
    #     LogisticRegression(max_iter=1000),
    #     SVC(probability=True)
    # ],
    'n_estimators': [50, 100],
    'max_samples': [0.5,1.0],
    'bootstrap': [True, False],
    'max_features': [0.5,1.0],
    'bootstrap_features': [True, False]
}

# %%
grid = GridSearchCV(BaggingClassifier(), parameters, cv=5, n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(cv=5, estimator=BaggingClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'max_features': [0.5, 1.0], 'max_samples': [0.5, 1.0],
#                          'n_estimators': [50, 100]},
#              verbose=1)

# %%
grid.best_estimator_
# Out:
# BaggingClassifier(max_features=0.5, max_samples=0.5, n_estimators=50)

# %%
grid.best_params_
# Out:
# {'bootstrap': True,
#  'bootstrap_features': False,
#  'max_features': 0.5,
#  'max_samples': 0.5,
#  'n_estimators': 50}
