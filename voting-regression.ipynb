# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()
rf = RandomForestRegressor()

# %%
estimators = [('lr', lr), ('dt', dt), ('svr', svr), ('rf', rf)]

# %%
for estimator in estimators:
    scores = cross_val_score(estimator[1], X,y, cv=10,scoring='r2')
    print(estimator[0], np.round(np.mean(scores),2))
# Out:
# lr 0.46
# dt -0.18
# svr 0.15
# rf 0.39

# %%
from sklearn.ensemble import VotingRegressor

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr, X,y, scoring='r2', cv=10)
print('VOting Regressor: ', np.round(np.mean(scores),2))
# Out:
# VOting Regressor:  0.37

# %%
for i in range(1,5):
    for j in range(1,5):
        for k in range(1,5):
            for l in range(1,5):
                vr = VotingRegressor(estimators, weights=[i,j,k,l])
                scores = cross_val_score(vr, X,y, cv=10, scoring='r2')
                print('for i={}, j={}, k={},l={}'.format(i,j,k,l), np.round(np.mean(scores),2))
# Out:
# for i=1, j=1, k=1,l=1 0.37
# for i=1, j=1, k=1,l=2 0.38
# for i=1, j=1, k=1,l=3 0.39
# for i=1, j=1, k=1,l=4 0.39
# for i=1, j=1, k=2,l=1 0.37
# for i=1, j=1, k=2,l=2 0.37
# for i=1, j=1, k=2,l=3 0.39
# for i=1, j=1, k=2,l=4 0.39
# for i=1, j=1, k=3,l=1 0.35
# for i=1, j=1, k=3,l=2 0.37
# for i=1, j=1, k=3,l=3 0.38
# for i=1, j=1, k=3,l=4 0.38
# for i=1, j=1, k=4,l=1 0.34
# for i=1, j=1, k=4,l=2 0.35
# for i=1, j=1, k=4,l=3 0.37
# for i=1, j=1, k=4,l=4 0.37
# for i=1, j=2, k=1,l=1 0.31
# for i=1, j=2, k=1,l=2 0.33
# for i=1, j=2, k=1,l=3 0.35
# for i=1, j=2, k=1,l=4 0.36
# for i=1, j=2, k=2,l=1 0.32
# for i=1, j=2, k=2,l=2 0.34
# for i=1, j=2, k=2,l=3 0.35
# for i=1, j=2, k=2,l=4 0.37
# for i=1, j=2, k=3,l=1 0.34
# for i=1, j=2, k=3,l=2 0.34
# for i=1, j=2, k=3,l=3 0.36
# for i=1, j=2, k=3,l=4 0.36
# for i=1, j=2, k=4,l=1 0.32
# for i=1, j=2, k=4,l=2 0.34
# for i=1, j=2, k=4,l=3 0.36
# for i=1, j=2, k=4,l=4 0.36
# for i=1, j=3, k=1,l=1 0.26
# for i=1, j=3, k=1,l=2 0.28
# for i=1, j=3, k=1,l=3 0.31
# for i=1, j=3, k=1,l=4 0.31
# for i=1, j=3, k=2,l=1 0.27
# for i=1, j=3, k=2,l=2 0.31
# for i=1, j=3, k=2,l=3 0.33
# for i=1, j=3, k=2,l=4 0.34
# for i=1, j=3, k=3,l=1 0.28
# for i=1, j=3, k=3,l=2 0.32
# for i=1, j=3, k=3,l=3 0.34
# for i=1, j=3, k=3,l=4 0.34
# for i=1, j=3, k=4,l=1 0.31
# for i=1, j=3, k=4,l=2 0.33
# for i=1, j=3, k=4,l=3 0.34
# for i=1, j=3, k=4,l=4 0.34
# for i=1, j=4, k=1,l=1 0.23
# for i=1, j=4, k=1,l=2 0.23
# for i=1, j=4, k=1,l=3 0.25
# for i=1, j=4, k=1,l=4 0.29
# for i=1, j=4, k=2,l=1 0.23
# for i=1, j=4, k=2,l=2 0.26
# for i=1, j=4, k=2,l=3 0.29
# for i=1, j=4, k=2,l=4 0.29
# for i=1, j=4, k=3,l=1 0.24
# for i=1, j=4, k=3,l=2 0.29
# for i=1, j=4, k=3,l=3 0.31
# for i=1, j=4, k=3,l=4 0.33
# for i=1, j=4, k=4,l=1 0.27
# for i=1, j=4, k=4,l=2 0.3
# for i=1, j=4, k=4,l=3 0.32
# for i=1, j=4, k=4,l=4 0.31
# for i=2, j=1, k=1,l=1 0.4
# for i=2, j=1, k=1,l=2 0.41
# for i=2, j=1, k=1,l=3 0.41
# for i=2, j=1, k=1,l=4 0.41
# for i=2, j=1, k=2,l=1 0.4
# for i=2, j=1, k=2,l=2 0.41
# for i=2, j=1, k=2,l=3 0.41
# for i=2, j=1, k=2,l=4 0.41
# for i=2, j=1, k=3,l=1 0.39
# for i=2, j=1, k=3,l=2 0.39
# for i=2, j=1, k=3,l=3 0.4
# for i=2, j=1, k=3,l=4 0.4
# for i=2, j=1, k=4,l=1 0.37
# for i=2, j=1, k=4,l=2 0.38
# for i=2, j=1, k=4,l=3 0.39
# for i=2, j=1, k=4,l=4 0.39
# for i=2, j=2, k=1,l=1 0.35
# for i=2, j=2, k=1,l=2 0.36
# for i=2, j=2, k=1,l=3 0.38
# for i=2, j=2, k=1,l=4 0.37
# for i=2, j=2, k=2,l=1 0.36
# for i=2, j=2, k=2,l=2 0.38
# for i=2, j=2, k=2,l=3 0.38
# for i=2, j=2, k=2,l=4 0.38
# for i=2, j=2, k=3,l=1 0.36
# for i=2, j=2, k=3,l=2 0.37
# for i=2, j=2, k=3,l=3 0.37
# for i=2, j=2, k=3,l=4 0.38
# for i=2, j=2, k=4,l=1 0.35
# for i=2, j=2, k=4,l=2 0.37
# for i=2, j=2, k=4,l=3 0.38
# for i=2, j=2, k=4,l=4 0.38
# for i=2, j=3, k=1,l=1 0.32
# for i=2, j=3, k=1,l=2 0.32
# for i=2, j=3, k=1,l=3 0.34
# for i=2, j=3, k=1,l=4 0.35
# for i=2, j=3, k=2,l=1 0.32
# for i=2, j=3, k=2,l=2 0.35
# for i=2, j=3, k=2,l=3 0.35
# for i=2, j=3, k=2,l=4 0.36
# for i=2, j=3, k=3,l=1 0.33
# for i=2, j=3, k=3,l=2 0.34
# for i=2, j=3, k=3,l=3 0.35
# for i=2, j=3, k=3,l=4 0.36
# for i=2, j=3, k=4,l=1 0.33
# for i=2, j=3, k=4,l=2 0.35
# for i=2, j=3, k=4,l=3 0.36
# for i=2, j=3, k=4,l=4 0.36
# for i=2, j=4, k=1,l=1 0.27
# for i=2, j=4, k=1,l=2 0.3
# for i=2, j=4, k=1,l=3 0.3
# for i=2, j=4, k=1,l=4 0.32
# for i=2, j=4, k=2,l=1 0.28
# for i=2, j=4, k=2,l=2 0.3
# for i=2, j=4, k=2,l=3 0.33
# for i=2, j=4, k=2,l=4 0.34
# for i=2, j=4, k=3,l=1 0.3
# for i=2, j=4, k=3,l=2 0.32
# for i=2, j=4, k=3,l=3 0.33
# for i=2, j=4, k=3,l=4 0.34
# for i=2, j=4, k=4,l=1 0.3
# for i=2, j=4, k=4,l=2 0.32
# for i=2, j=4, k=4,l=3 0.33
# for i=2, j=4, k=4,l=4 0.34
# for i=3, j=1, k=1,l=1 0.42
# for i=3, j=1, k=1,l=2 0.43
# for i=3, j=1, k=1,l=3 0.42
# for i=3, j=1, k=1,l=4 0.42
# for i=3, j=1, k=2,l=1 0.42
# for i=3, j=1, k=2,l=2 0.42
# for i=3, j=1, k=2,l=3 0.42
# for i=3, j=1, k=2,l=4 0.42
# for i=3, j=1, k=3,l=1 0.41
# for i=3, j=1, k=3,l=2 0.41
# for i=3, j=1, k=3,l=3 0.42
# for i=3, j=1, k=3,l=4 0.41
# for i=3, j=1, k=4,l=1 0.39
# for i=3, j=1, k=4,l=2 0.4
# for i=3, j=1, k=4,l=3 0.4
# for i=3, j=1, k=4,l=4 0.4
# for i=3, j=2, k=1,l=1 0.38
# for i=3, j=2, k=1,l=2 0.39
# for i=3, j=2, k=1,l=3 0.39
# for i=3, j=2, k=1,l=4 0.39
# for i=3, j=2, k=2,l=1 0.38
# for i=3, j=2, k=2,l=2 0.4
# for i=3, j=2, k=2,l=3 0.4
# for i=3, j=2, k=2,l=4 0.41
# for i=3, j=2, k=3,l=1 0.38
# for i=3, j=2, k=3,l=2 0.39
# for i=3, j=2, k=3,l=3 0.39
# for i=3, j=2, k=3,l=4 0.4
# for i=3, j=2, k=4,l=1 0.37
# for i=3, j=2, k=4,l=2 0.38
# for i=3, j=2, k=4,l=3 0.39
# for i=3, j=2, k=4,l=4 0.4
# for i=3, j=3, k=1,l=1 0.34
# for i=3, j=3, k=1,l=2 0.35
# for i=3, j=3, k=1,l=3 0.36
# for i=3, j=3, k=1,l=4 0.36
# for i=3, j=3, k=2,l=1 0.35
# for i=3, j=3, k=2,l=2 0.37
# for i=3, j=3, k=2,l=3 0.37
# for i=3, j=3, k=2,l=4 0.38
# for i=3, j=3, k=3,l=1 0.37
# for i=3, j=3, k=3,l=2 0.37
# for i=3, j=3, k=3,l=3 0.37
# for i=3, j=3, k=3,l=4 0.38
# for i=3, j=3, k=4,l=1 0.36
# for i=3, j=3, k=4,l=2 0.37
# for i=3, j=3, k=4,l=3 0.37
# for i=3, j=3, k=4,l=4 0.38
# for i=3, j=4, k=1,l=1 0.3
# for i=3, j=4, k=1,l=2 0.31
# for i=3, j=4, k=1,l=3 0.33
# for i=3, j=4, k=1,l=4 0.34
# for i=3, j=4, k=2,l=1 0.31
# for i=3, j=4, k=2,l=2 0.34
# for i=3, j=4, k=2,l=3 0.35
# for i=3, j=4, k=2,l=4 0.35
# for i=3, j=4, k=3,l=1 0.32
# for i=3, j=4, k=3,l=2 0.34
# for i=3, j=4, k=3,l=3 0.36
# for i=3, j=4, k=3,l=4 0.36
# for i=3, j=4, k=4,l=1 0.34
# for i=3, j=4, k=4,l=2 0.35
# for i=3, j=4, k=4,l=3 0.37
# for i=3, j=4, k=4,l=4 0.37
# for i=4, j=1, k=1,l=1 0.43
# for i=4, j=1, k=1,l=2 0.44
# for i=4, j=1, k=1,l=3 0.43
# for i=4, j=1, k=1,l=4 0.43
# for i=4, j=1, k=2,l=1 0.42
# for i=4, j=1, k=2,l=2 0.44
# for i=4, j=1, k=2,l=3 0.43
# for i=4, j=1, k=2,l=4 0.43
# for i=4, j=1, k=3,l=1 0.41
# for i=4, j=1, k=3,l=2 0.42
# for i=4, j=1, k=3,l=3 0.42
# for i=4, j=1, k=3,l=4 0.42
# for i=4, j=1, k=4,l=1 0.4
# for i=4, j=1, k=4,l=2 0.41
# for i=4, j=1, k=4,l=3 0.42
# for i=4, j=1, k=4,l=4 0.41
# for i=4, j=2, k=1,l=1 0.4
# for i=4, j=2, k=1,l=2 0.4
# for i=4, j=2, k=1,l=3 0.41
# for i=4, j=2, k=1,l=4 0.41
# for i=4, j=2, k=2,l=1 0.39
# for i=4, j=2, k=2,l=2 0.41
# for i=4, j=2, k=2,l=3 0.41
# for i=4, j=2, k=2,l=4 0.41
# for i=4, j=2, k=3,l=1 0.4
# for i=4, j=2, k=3,l=2 0.4
# for i=4, j=2, k=3,l=3 0.4
# for i=4, j=2, k=3,l=4 0.41
# for i=4, j=2, k=4,l=1 0.39
# for i=4, j=2, k=4,l=2 0.4
# for i=4, j=2, k=4,l=3 0.4
# for i=4, j=2, k=4,l=4 0.4
# for i=4, j=3, k=1,l=1 0.36
# for i=4, j=3, k=1,l=2 0.38
# for i=4, j=3, k=1,l=3 0.38
# for i=4, j=3, k=1,l=4 0.38
# for i=4, j=3, k=2,l=1 0.37
# for i=4, j=3, k=2,l=2 0.38
# for i=4, j=3, k=2,l=3 0.39
# for i=4, j=3, k=2,l=4 0.4
# for i=4, j=3, k=3,l=1 0.37
# for i=4, j=3, k=3,l=2 0.38
# for i=4, j=3, k=3,l=3 0.39
# for i=4, j=3, k=3,l=4 0.39
# for i=4, j=3, k=4,l=1 0.37
# for i=4, j=3, k=4,l=2 0.39
# for i=4, j=3, k=4,l=3 0.39
# for i=4, j=3, k=4,l=4 0.39
# for i=4, j=4, k=1,l=1 0.32
# for i=4, j=4, k=1,l=2 0.34
# for i=4, j=4, k=1,l=3 0.36
# for i=4, j=4, k=1,l=4 0.37
# for i=4, j=4, k=2,l=1 0.34
# for i=4, j=4, k=2,l=2 0.36
# for i=4, j=4, k=2,l=3 0.37
# for i=4, j=4, k=2,l=4 0.37
# for i=4, j=4, k=3,l=1 0.35
# for i=4, j=4, k=3,l=2 0.36
# for i=4, j=4, k=3,l=3 0.36
# for i=4, j=4, k=3,l=4 0.36
# for i=4, j=4, k=4,l=1 0.36
# for i=4, j=4, k=4,l=2 0.36
# for i=4, j=4, k=4,l=3 0.38
# for i=4, j=4, k=4,l=4 0.37

# %%
vr = VotingRegressor(estimators, weights=[3,1,1])
scores = cross_val_score(vr, X,y,cv=10,scoring='r2')
print(np.round(np.mean(scores),2))
# Out:
# 0.41

# %%
# using the same algorithm

dt1 = DecisionTreeRegressor(max_depth=1)
dt2 = DecisionTreeRegressor(max_depth=3)
dt3 = DecisionTreeRegressor(max_depth=5)
dt4 = DecisionTreeRegressor(max_depth=7)
dt5 = DecisionTreeRegressor(max_depth=None)

# %%
estimators = [('dt1', dt1), ('dt2', dt2), ('dt3', dt3), ('dt4', dt4), ('dt5', dt5)]

# %%
for estimator in estimators:
    scores = cross_val_score(estimator[1], X,y,cv=10, scoring='r2')
    print(estimator[0], np.round(np.mean(scores),2))
# Out:
# dt1 0.15
# dt2 0.29
# dt3 0.15
# dt4 -0.06
# dt5 -0.2

# %%
vr = VotingRegressor(estimators)
scores = cross_val_score(vr, X,y,cv=10, scoring='r2')
print('Voting Regressor', np.round(np.mean(scores),2))
# Out:
# Voting Regressor 0.22
